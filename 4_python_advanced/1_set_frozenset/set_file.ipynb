# %%
from IPython.display import display
from PIL import Image

# %%
my_set = set([1,2,3,2,4,5,2,3,5])
my_set
# Out:
# {1, 2, 3, 4, 5}

# %%
menu = set(["Burger", "Pizza", "Pasta"])
menu
# Out:
# {'Burger', 'Pasta', 'Pizza'}

# %%
menu.add("Sushi")
menu
# Out:
# {'Burger', 'Pasta', 'Pizza', 'Sushi'}

# %%
menu.add("Biryani")
menu
# Out:
# {'Biryani', 'Burger', 'Pasta', 'Pizza', 'Sushi'}

# %%
menu = frozenset(["Burger", "Pizza", "Pasta"])
menu
# Out:
# frozenset({'Burger', 'Pasta', 'Pizza'})

# %%
menu = set(["Burger", "Pizza", "Pasta"])
menu
# Out:
# {'Burger', 'Pasta', 'Pizza'}

# %%
"Pizza" in menu
# Out:
# True

# %%
"Burger" in menu
# Out:
# True

# %%
transactions = [
    {"customer_name": "Aarav", "amount": 120.5, "date": "2024-10-15"},
    {"customer_name": "Fatima", "amount": 45.7, "date": "2024-10-18"},
    {"customer_name": "Aarav", "amount": 78.9, "date": "2024-11-01"},
    {"customer_name": "Zoya", "amount": 99.3, "date": "2024-11-05"},
    {"customer_name": "Fatima", "amount": 150.2, "date": "2024-11-10"},
    {"customer_name": "Ibrahim", "amount": 60.0, "date": "2024-11-12"},
]

# %%
customers = set()

for transaction in transactions:
    customers.add(transaction["customer_name"])
print(customers)
# Out:
# {'Aarav', 'Fatima', 'Ibrahim', 'Zoya'}

# %%
customers_list = list(customers)
customers_list
# Out:
# ['Aarav', 'Fatima', 'Ibrahim', 'Zoya']

# %%
tennis_class = {"Aarav", "Fatima", "Zoya", "Ibrahim", "Rohan"}
volleyball_class = {"Fatima", "Ibrahim", "Mira", "Yash", "Nina"}

# %% [markdown]
# So let's say this is set A, this is set B, and whatever is common is called intersection. So when you're doing A or B, then it'll give you all the elements, see all the elements which are in A and B. So let's get a list of all the students that I have.

# %%
img = Image.open("img.png")
img_resized = img.resize((400, 300))  # Resize to 400x300 pixels
display(img_resized)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x300>

# %%
tennis_class | volleyball_class
# Out:
# {'Aarav', 'Fatima', 'Ibrahim', 'Mira', 'Nina', 'Rohan', 'Yash', 'Zoya'}

# %%
tennis_class & volleyball_class
# Out:
# {'Fatima', 'Ibrahim'}

# %%
tennis_class.intersection(volleyball_class)
# Out:
# {'Fatima', 'Ibrahim'}

# %%
tennis_class.union(volleyball_class)
# Out:
# {'Aarav', 'Fatima', 'Ibrahim', 'Mira', 'Nina', 'Rohan', 'Yash', 'Zoya'}

# %%
img = Image.open("img2.png")
img_resized = img.resize((400, 300))  # Resize to 400x300 pixels
display(img_resized)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x300>

# %%
tennis_class - volleyball_class
# Out:
# {'Aarav', 'Rohan', 'Zoya'}
