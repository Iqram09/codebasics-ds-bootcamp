# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

df_sales = pd.read_excel('linechart.xlsx')
df_sales.head()
# Out:
#    Quarter  Fridge  Dishwasher  Washing Machine
# 0  Q1 2022    12.5         8.0              9.2
# 1  Q2 2022    11.0         7.5              8.5
# 2  Q3 2022    13.2         9.0              7.5
# 3  Q4 2022    16.4        11.0              7.6
# 4  Q1 2023    13.8         9.5              6.8

# %%
plt.figure(figsize=(12,4))
plt.plot(df_sales['Quarter'], df_sales['Fridge'],color='red',label='Fridge')
plt.plot(df_sales['Quarter'], df_sales['Dishwasher'],color='blue',label='Dishwasher')
plt.plot(df_sales['Quarter'], df_sales['Washing Machine'],color='green',label='Washing Machine')

plt.title('Sales by Quarter')
plt.xlabel('Finacial Quarter')
plt.ylabel('Revenue (mln $)')
plt.legend()

# %%
total_sales = df_sales[['Fridge','Dishwasher','Washing Machine']].sum()
print(total_sales)
# Out:
# Fridge             80.9
# Dishwasher         53.0
# Washing Machine    45.6
# dtype: float64

# %%
plt.pie(total_sales,labels= total_sales.index,autopct='%1.1f%%',explode=(0.1,0,0),shadow=True,startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1435574ba10>,
#   <matplotlib.patches.Wedge at 0x1433d013830>,
#   <matplotlib.patches.Wedge at 0x143557335c0>],
#  [Text(-1.1856338598258607, 0.18512792991450855, 'Fridge'),
#   Text(0.6371831599490939, -0.8966591440883696, 'Dishwasher'),
#   Text(0.7876240099114379, 0.7678856809519419, 'Washing Machine')],
#  [Text(-0.6916197515650854, 0.10799129245012998, '45.1%'),
#   Text(0.3475544508813239, -0.4890868058663833, '29.5%'),
#   Text(0.4296130963153297, 0.4188467350646955, '25.4%')])

# %%
df_sales.plot(kind='bar',x='Quarter')
# Out:
# <Axes: xlabel='Quarter'>

# %%
df_score = pd.read_excel('histograms.xlsx')
df_score.head()
# Out:
#        Name  Exam_Score
# 0     Aarav          45
# 1   Michael          71
# 2     Bilal          59
# 3  Priyanka          92
# 4    Sophia           0

# %%
sns.histplot(data =df_score, x ="Exam_Score",kde=True)

plt.xlabel('score')
plt.ylabel('count')
plt.title('Exam Score')
plt.show()

# %%
df = pd.read_excel('scatter_plot.xlsx')
df.head()
# Out:
#    area_square_ft  price
# 0             650     55
# 1             800     91
# 2             950     96
# 3            1100    122
# 4             500     34

# %%
sns.scatterplot(data= df,x="area_square_ft", y="price")
# Out:
# <Axes: xlabel='area_square_ft', ylabel='price'>
